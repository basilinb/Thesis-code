# %%
library("DESeq2")
package.version("DESeq2")
#Version says 1.22.1

#activating phyloseq
#BiocManager::install("phyloseq")
library("phyloseq")
package.version("phyloseq")
#Version says 1.26.0

library("ggplot2")
packageVersion("ggplot2")
#Package version of ggplot2 is 3.1.0

library("biomformat")
packageVersion("biomformat")
#Package version of biomformat is 1.10.0

library("vegan")
packageVersion('vegan')
#Package version of vegen is 2.5.3

library("grid")
packageVersion('grid')
#Package version of grid is 3.5.1

library(magrittr)
packageVersion('magrittr')
#Package version of magrittr is 1.5

library(dplyr)
packageVersion("dplyr")
#Package version of dplyr is 0.7.8

library(plyr)
packageVersion("plyr")
#Package version of plyr is 1.8.4

library(broom)
packageVersion("broom")
#Package version of broom is 0.5.1

library('stringr')
packageVersion("stringr")
#Package version of stringr is 1.3.1

library('knitr')
packageVersion('knitr')
#Package version of knitr is 1.21

package.version("BiocManager")
#Version says 1.30.4

library(gridExtra)
library(grid)
library("ggplotify")

R.version
#R version is 3.5.1
# Out:
# [1] "1.18.1"
# [1] "1.22.3"
# [1] ‘3.2.1’
# [1] ‘1.6.0’
# [1] ‘2.5.6’
# [1] ‘3.4.1’
# [1] ‘1.5’
# [1] ‘0.8.4’
# [1] ‘1.8.5’
# [1] ‘0.5.4’
# [1] ‘1.4.0’
# [1] ‘1.28’
# [1] "1.30.10"
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          3
# minor          4.1
# year           2017
# month          06
# day            30
# svn rev        72865
# language       R
# version.string R version 3.4.1 (2017-06-30)
# nickname       Single Candle

# %%
#Importing Qiime1 data
biom_all_mice <- import_biom(BIOMfilename = "otu_table_filtered_s24-json.biom"
            ,treefilename = "rep_set.tre"
            ,parseFunction = parse_taxonomy_greengenes)

#Importing mapping file
mapping_file <- import_qiime_sample_data(mapfilename = "pcos_mapping.tsv")

#Merging both mapping file phyloseq object and biom file phyloseq data
physeq <- merge_phyloseq(biom_all_mice, mapping_file)
# Out:
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”
# Warning message in parseFunction(i$metadata$taxonomy):
# “No greengenes prefixes were found.
# Consider using parse_taxonomy_default() instead if true for all OTUs.
# Dummy ranks may be included among taxonomic ranks now.”

# %%
physeq.pt = subset_samples(physeq, Time != '0') # removing time 0
# Subset data by time
physeq.pt.time0 = subset_samples(physeq, Time != '1' & Time!='3' & Time!='4' & Time!='5' & Time!='2')
physeq.pt.time2 = subset_samples(physeq.pt, Time != '1' & Time!='3' & Time!='4' & Time!='5')
physeq.pt.time5 = subset_samples(physeq.pt, Time != '1' & Time!='3' & Time!='4' & Time!='2')
physeq.pt.time1 = subset_samples(physeq.pt, Time != '2' & Time!='3' & Time!='4' & Time!='5')
physeq.pt.time3 = subset_samples(physeq.pt, Time != '1' & Time!='5' & Time!='4' & Time!='2')
physeq.pt.time4 = subset_samples(physeq.pt, Time != '1' & Time!='3' & Time!='2' & Time!='5')

# %%
physeq
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 2517 taxa and 119 samples ]
# sample_data() Sample Data:       [ 119 samples by 12 sample variables ]
# tax_table()   Taxonomy Table:    [ 2517 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 2517 tips and 2516 internal nodes ]

# %%
unique(sample_data(physeq.pt.time0)$Treat)
unique(sample_data(physeq.pt.time0)$Time)
# Out:
# [1] P L
# Levels: L P
# [1] 0

# %% [markdown]
# ## TIME POINT 0

# %%
depths <- sample_sums(physeq.pt.time0)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time0)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time0)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time0)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time0)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   15243   18356   25638   25664   28925   54131
# [1] "Number of Samples in our Biom Table"
# [1] 20
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   15243   18356   25638   25664   28925   54131
# B01L0F B08L0I A01P0A A05P0C B09L0J A10P0E B06L0H A09P0E B05L0H B03L0G A04P0B
#  15243  15805  16869  17338  17798  18542  19149  24705  24911  25360  25917
# B04L0G A03P0B B07L0I B10L0J A08P0D B02L0F A02P0A A07P0D A06P0C
#  26045  26723  28494  28607  29879  30766  32953  34043  54131
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time0, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time0)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 62OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
set.seed(1)
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "wunifrac")
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time0_ellipse.pdf', width=8, height=7)
p0 = plot(CategorybetaDNA, ellipse = TRUE, hull=F)


#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.005601 0.0056012 0.6613    999  0.446
# Residuals 18 0.152470 0.0084706
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.005601 0.0056012 0.6613    999  0.434
# Residuals 18 0.152470 0.0084706
# png
#   2

# %%
df = as(sample_data(meta.rarefy), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE) # distance matrix

set.seed(2)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs MeanSqs   F.Model  R2         Pr(>F)
# Treat      1 0.1365457 0.1365457 1.269962 0.06590372 0.249
# Residuals 18 1.9353511 0.1075195       NA 0.93409628    NA
# Total     19 2.0718968        NA       NA 1.00000000    NA

# %% [markdown]
# ## TIME POINT 1

# %%
depths <- sample_sums(physeq.pt.time1)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time1)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time1)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time1)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time1)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12409   15844   21174   22246   26828   37840
# [1] "Number of Samples in our Biom Table"
# [1] 20
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12409   15844   21174   22246   26828   37840
# D04L1G D10L1J C04P1B D02L1F D09L1J D07L1I C08P1D C06P1C C05P1C D01L1F C09P1E
#  12409  12984  13531  14381  15810  15855  17762  20311  20724  20945  21402
# C01P1A D03L1G C02P1A C10P1E C07P1D D06L1H C03P1B D05L1H D08L1I
#  22373  22466  25102  26565  27619  29880  30282  36669  37840
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time1, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time1)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 16OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "wunifrac")
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time1_ellipse.pdf', width=8, height=7)
p1 = plot(CategorybetaDNA, ellipse = TRUE, hull=F)
#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.005601 0.0056012 0.6613    999  0.411
# Residuals 18 0.152470 0.0084706
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.005601 0.0056012 0.6613    999  0.437
# Residuals 18 0.152470 0.0084706
# png
#   2

# %%
df = as(sample_data(meta.rarefy), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE) # distance matrix

#set.seed(2)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs  MeanSqs    F.Model  R2         Pr(>F)
# Treat      1 0.09104982 0.09104982 1.075111 0.05636197 0.322
# Residuals 18 1.52439809 0.08468878       NA 0.94363803    NA
# Total     19 1.61544791         NA       NA 1.00000000    NA

# %% [markdown]
# ## TIME POINT 2

# %%
depths <- sample_sums(physeq.pt.time2)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time2)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time2)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time2)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time2)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12962   19412   23780   22432   25840   31123
# [1] "Number of Samples in our Biom Table"
# [1] 20
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12962   19412   23780   22432   25840   31123
# E01P2A E10P2E F05L2H E08P2D F10L2J F09L2J F08L2I F03L2G F07L2I F04L2G E06P2C
#  12962  14251  14934  16758  19180  19490  19990  21256  22536  23492  24067
# E05P2C F01L2F E09P2E E02P2A F06L2H F02L2F E04P2B E03P2B E07P2D
#  24307  24675  25788  25801  25956  27090  27446  27538  31123
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time2, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time2)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 13OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "wunifrac")
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time2_ellipse.pdf', width=8, height=7)
p2 = plot(CategorybetaDNA, ellipse = TRUE, hull=F, main = "PCOA TIME 2")
#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.001324 0.0013243 0.2452    999  0.617
# Residuals 18 0.097216 0.0054009
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.001324 0.0013243 0.2452    999  0.631
# Residuals 18 0.097216 0.0054009
# png
#   2

# %%
df = as(sample_data(physeq.pt.time2), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(physeq.pt.time2, "unifrac", weighted=TRUE) # distance matrix

set.seed(11)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs MeanSqs    F.Model R2         Pr(>F)
# Treat      1 0.1214652 0.12146518 1.76967 0.08951439 0.058
# Residuals 18 1.2354694 0.06863719      NA 0.91048561    NA
# Total     19 1.3569346         NA      NA 1.00000000    NA

# %% [markdown]
# ## TIME POINT 3

# %%
depths <- sample_sums(physeq.pt.time3)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time3)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time2)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time3)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time3)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12761   17603   20933   22528   25694   47588
# [1] "Number of Samples in our Biom Table"
# [1] 20
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12761   17603   20933   22528   25694   47588
# H08L3I H02L3F H10L3J G10P3E H03L3G H05L3H G09P3E G03P3B H01L3F H06L3H G01P3A
#  12761  13250  14306  16042  17221  17730  18531  19639  19949  20226  21640
# H04L3G H09L3J G02P3A G06P3C G05P3C G04P3B G08P3D H07L3I G07P3D
#  22911  23788  23990  25594  25994  29069  29407  30917  47588
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time3, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time3)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 23OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "wunifrac")
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time3_ellipse.pdf', width=8, height=7)
p3 = plot(CategorybetaDNA, ellipse = TRUE, hull=F, main = "PCOA TIME 3")
#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq     F N.Perm Pr(>F)
# Groups     1 0.007567 0.0075669 1.571    999  0.201
# Residuals 18 0.086696 0.0048164
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq     F N.Perm Pr(>F)
# Groups     1 0.007567 0.0075669 1.571    999  0.222
# Residuals 18 0.086696 0.0048164
# png
#   2

# %%
df = as(sample_data(meta.rarefy), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE) # distance matrix

set.seed(2)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs MeanSqs   F.Model  R2       Pr(>F)
# Treat      1 0.214336  0.2143360 2.755763 0.132771 0.015
# Residuals 18 1.399993  0.0777774       NA 0.867229    NA
# Total     19 1.614329         NA       NA 1.000000    NA

# %% [markdown]
# ## TIME POINT 4

# %%
depths <- sample_sums(physeq.pt.time4)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time4)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time4)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time4)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time4)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    7450   20572   23677   23575   28129   37875
# [1] "Number of Samples in our Biom Table"
# [1] 19
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    7450   20572   23677   23575   28129   37875
# B06L4H B08L4I A08P4D A02P4A A05P4C A03P4B A06P4C B07L4I B03L4G A07P4D A01P4A
#   7450  12433  13554  15844  20551  20594  20888  21204  21969  23677  24151
# B01L4F A10P4E B02L4F B09L4J B10L4J B04L4G B05L4H A09P4E
#  25360  25878  25917  30341  30791  32359  37098  37875
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time4, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time4)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 166OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE)
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time4_ellipse.pdf', width=8, height=7)
p4 = plot(CategorybetaDNA, ellipse = TRUE, hull=F, main = "PCOA TIME 4")
#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.000432 0.0004323 0.0713    999  0.812
# Residuals 17 0.103121 0.0060660
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.000432 0.0004323 0.0713    999  0.784
# Residuals 17 0.103121 0.0060660
# png
#   2

# %%
df = as(sample_data(meta.rarefy), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE) # distance matrix

set.seed(123)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs  MeanSqs    F.Model  R2         Pr(>F)
# Treat      1 0.04947834 0.04947834 0.622689 0.03533451 0.801
# Residuals 17 1.35080553 0.07945915       NA 0.96466549    NA
# Total     18 1.40028387         NA       NA 1.00000000    NA

# %% [markdown]
# ## TIME POINT 5

# %%
depths <- sample_sums(physeq.pt.time5)
summary(depths)
hist(depths)

# Start to explore the data a bit 
#number of samples
print ('Number of Samples in our Biom Table')
nsamples(physeq.pt.time5)
# number of sequence variants
print ('Number of Sequence variants we have.')
ntaxa(physeq.pt.time5)
#summary statistics of sampling depth
print ('Sequencing depth.')
depths <- sample_sums(physeq.pt.time5)
summary(depths)
hist(depths)
head(sort(sample_sums(physeq.pt.time5)),25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12314   19998   23482   25789   32422   45858
# [1] "Number of Samples in our Biom Table"
# [1] 20
# [1] "Number of Sequence variants we have."
# [1] 2517
# [1] "Sequencing depth."
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12314   19998   23482   25789   32422   45858
# D01L5F C06P5C D09L5J D03L5G D06L5H D07L5I C02P5A D05L5H C04P5B C03P5B D02L5F
#  12314  12603  14021  15988  17027  20988  21012  21665  22714  23044  23920
# D08L5I D10L5J C05P5C D04L5G C08P5D C10P5E C07P5D C01P5A C09P5E
#  26064  30232  30385  32290  32818  34321  34900  43618  45858
# Plot with title “Histogram of depths”

# %%
set.seed(123)
meta.rarefy = rarefy_even_depth(physeq.pt.time5, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time5)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...
#
# 22OTUs were removed because they are no longer
# present in any sample after random subsampling
#
#
# ...

# %%
df = as(sample_data(meta.rarefy), "data.frame")
d = phyloseq::distance(meta.rarefy, "wunifrac")
#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy))
beta <- betadisper(d, sampledf$Treat)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Treat)
permutest(CategorybetaDNA)

pdf('Time5_ellipse.pdf', width=8, height=7)
p5 = plot(CategorybetaDNA, ellipse = TRUE, hull=F)
#boxplot(CategorybetaDNA)
dev.off()
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq  Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.003083 0.003083 0.7391    999  0.395
# Residuals 18 0.075079 0.004171
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq  Mean Sq      F N.Perm Pr(>F)
# Groups     1 0.003083 0.003083 0.7391    999  0.406
# Residuals 18 0.075079 0.004171
# png
#   2

# %%
df = as(sample_data(meta.rarefy), "data.frame") # this is our mapping file inside our phyloseq object being converted to a dataframe
d = phyloseq::distance(meta.rarefy, "unifrac", weighted=TRUE) # distance matrix

set.seed(4)
a=adonis(d ~ Treat, df, permutations=999, method='unifrac', weighted=TRUE)
a$aov.tab
# Out:
#           Df SumsOfSqs MeanSqs    F.Model  R2         Pr(>F)
# Treat      1 0.0859355 0.08593550 1.086381 0.05691915 0.341
# Residuals 18 1.4238464 0.07910258       NA 0.94308085    NA
# Total     19 1.5097820         NA       NA 1.00000000    NA

# %% [markdown]
# ![Time_ellipse_all_final.pdf.png](attachment:Time_ellipse_all_final.pdf.png)
